# %% [markdown]
# # Data Science Project Submission

# %% [markdown]
# ### Submitted By:
#
# - Name: Srishti Tripathi
# - Roll No: 202210101150024
# - Course: B.tech CSE(DS+AI) - 51,52
#
# ### Submitted To:
#
# - Name: Mr. Raman Kumar

# %% [markdown]
# ### Project Overview
#
# - Script Format : Jupyter Notebook (.ipynb extension)
# - Dataset Used : "titanic.csv"
# - Project Report : Summarizes the following components:
#     - Data Cleaning : Preprocessing the dataset for analysis
#     - Data Manipulation : Transformation and filtering of data for insights
#     - Key Insights : Patterns and trends identified through the analysis
#     - Visualizations : Graphical representation of the data findings
#     - Conclusion : A summary of the results and key findings from the analysis.

# %% [markdown]
# ## Data Selection :
#
# - Dataset: I used the "Titanic" dataset. It contains information about the PassengerId, Survived, Pclass, Name, Sex, Age, Number of Siblings, Parents, Ticket, Fare, Cabin and Embarked

# %% [markdown]
# # Task 1 : Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 2 : Load the dataset

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Task 3 : Data Cleaning

# %% [markdown]
# - 3.1 Count the number of missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# - 3.2 Count the number of duplicate values

# %%
print(df.duplicated().sum()) # Here we cam see there are no duplicate values in the dataset
# Out:
# 0

# %% [markdown]
# - 3.3 Removing rows with missing values

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# - 3.4 Checking for missing values after cleaning

# %%
df.isnull().sum()

# now we can see there are no null values left in the dataset
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# - 3.5 Display the cleaned dataset's first few rows

# %%
print("Cleaned dataset (first few rows) : ")
df.head()
# Out:
# Cleaned dataset (first few rows) :
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %% [markdown]
# # Task 4 : Data Manipulation

# %%
df = df.drop(['Cabin'], axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(['Parch'], axis=1)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
#          Ticket      Fare Embarked
# 12        21228   82.2667        S
# 14  W.E.P. 5734   61.1750        S
# 24     PC 17608  262.3750        C
# 26       113509   61.9792        C
# 28       113054   30.5000        S

# %% [markdown]
# # Task 5 : Descriptive Analysis

# %%
df["Survived"].value_counts()  # Here 0 means dead and 1 means alive
# Out:
# Survived
# 1    44
# 0    43
# Name: count, dtype: int64

# %%
df[['PassengerId','Name', 'Survived']].sort_values('Survived', ascending=False)
# Out:
#      PassengerId                                               Name  Survived
# 12           904      Snyder, Mrs. John Pillsbury (Nelle Stevenson)         1
# 14           906  Chaffee, Mrs. Herbert Fuller (Carrie Constance...         1
# 24           916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)         1
# 26           918                       Ostby, Miss. Helene Ragnhild         1
# 44           936   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)         1
# ..           ...                                                ...       ...
# 378         1270                        Hipkins, Mr. William Edward         0
# 390         1282                         Payne, Mr. Vivian Ponsonby         0
# 404         1296                       Frauenthal, Mr. Isaac Gerald         0
# 407         1299                         Widener, Mr. George Dunton         0
# 405         1297       Nourney, Mr. Alfred (Baron von Drachstedt")"         0
#
# [87 rows x 3 columns]

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 1    78
# 2     6
# 3     3
# Name: count, dtype: int64

# %%
df[['PassengerId','Name','Pclass', 'Survived']].sort_values('Survived', ascending=False)
# Out:
#      PassengerId                                               Name  Pclass  \
# 12           904      Snyder, Mrs. John Pillsbury (Nelle Stevenson)       1
# 14           906  Chaffee, Mrs. Herbert Fuller (Carrie Constance...       1
# 24           916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)       1
# 26           918                       Ostby, Miss. Helene Ragnhild       1
# 44           936   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)       1
# ..           ...                                                ...     ...
# 378         1270                        Hipkins, Mr. William Edward       1
# 390         1282                         Payne, Mr. Vivian Ponsonby       1
# 404         1296                       Frauenthal, Mr. Isaac Gerald       1
# 407         1299                         Widener, Mr. George Dunton       1
# 405         1297       Nourney, Mr. Alfred (Baron von Drachstedt")"       2
#
#      Survived
# 12          1
# 14          1
# ...

# %%
survive = df['Survived'] == 1
survive.value_counts().values[1]
# Out:
# np.int64(43)

# %%
df[survive] # passengers that survived
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 44           936         1       1
# 48           940         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 117         1009         1       3
# 122         1014         1       1
# 150         1042         1       1
# 156         1048         1       1
# 178         1070         1       2
# 179         1071         1       1
# 182         1074         1       1
# 184         1076         1       1
# 208         1100         1       1
# ...

# %%
adult = df['Age'] >= 18
adult.value_counts().values[1]
# Out:
# np.int64(4)

# %%
# df[df[survive, adult]]

# %% [markdown]
# # Data Analysis
